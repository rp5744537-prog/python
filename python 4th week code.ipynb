# %%
print("===LIST EXAMPLE===")
fruits=["apple","banana","orange"] #duplicate allowed
print("original list",fruits)
# Out:
# ===LIST EXAMPLE===
# original list ['apple', 'banana', 'orange']

# %%
print("/n===TULIP EXAMPLE===")
coordinates=(10.5,20.3,10.5)
print("Tulip",coordinates)
print("First coordinate",coordinates[0])
# Out:
# /n===TULIP EXAMPLE===
# Tulip (10.5, 20.3, 10.5)
# First coordinate 10.5

# %%
print("/n===TULIP EXAMPLE===")
coordinates=(10.5,20.3,10.5)
print("Tulip",coordinates)
print("First coordinate",coordinates[-1])
# Out:
# /n===TULIP EXAMPLE===
# Tulip (10.5, 20.3, 10.5)
# First coordinate 10.5

# %%
#create alis tof 5 numbers and print all elements
#print first and last element of a list[10,20,30,40,50]
#add number 100 to the list[1,2,3,4]
#remove element 3 from the list[1,2,3,4,5]
#find the sum of all elements in[5,10,15,20]
#find the maximum and minimum in[8,3,9,1,6]

# %%
numbers = [1, 2, 3, 4, 5]
print("All elements:", numbers)
# Out:
# All elements: [1, 2, 3, 4, 5]

# %%
list1 = [10, 20, 30, 40, 50]
print("First element:", list1[0])
print("Last element:", list1[-1])
# Out:
# First element: 10
# Last element: 50

# %%
list2 = [1, 2, 3, 4]
list2.append(100)
print("After adding 100:", list2)
# Out:
# After adding 100: [1, 2, 3, 4, 100]

# %%
list3 = [1, 2, 3, 4, 5]
list3.remove(3)
print("After removing 3:", list3)
# Out:
# After removing 3: [1, 2, 4, 5]

# %%
list4 = [5, 10, 15, 20]
print("Sum of elements:", sum(list4))
# Out:
# Sum of elements: 50

# %%
list5 = [8, 3, 9, 1, 6]
print("Maximum:", max(list5))
print("Minimum:", min(list5))
# Out:
# Maximum: 9
# Minimum: 1
